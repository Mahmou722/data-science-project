# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
pd.set_option('display.max_columns',None)#تحديد عدد الاعمدة اللي تظهر

# %%
df=pd.read_csv('train.csv')

# %%
df.head(n=10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %% [markdown]
# # mising value

# %%
feature_null=[i for i in df.columns if df[i].isnull().sum()>0 ]
for i in feature_null:
    print(i,":",df[i].isnull().sum())
# Out:
# LotFrontage : 259
# Alley : 1369
# MasVnrType : 8
# MasVnrArea : 8
# BsmtQual : 37
# BsmtCond : 37
# BsmtExposure : 38
# BsmtFinType1 : 37
# BsmtFinType2 : 38
# Electrical : 1
# FireplaceQu : 690
# GarageType : 81
# GarageYrBlt : 81
# GarageFinish : 81
# GarageQual : 81
# GarageCond : 81
# PoolQC : 1453
# Fence : 1179
# MiscFeature : 1406

# %%
df['LotFrontage'].isnull().sum()
# Out:
# 259

# %%
for i in (feature_null):
    print(i,np.round(df[i].isnull().mean(),2),"% mising_value ")
# Out:
# LotFrontage 0.18 % mising_value
# Alley 0.94 % mising_value
# MasVnrType 0.01 % mising_value
# MasVnrArea 0.01 % mising_value
# BsmtQual 0.03 % mising_value
# BsmtCond 0.03 % mising_value
# BsmtExposure 0.03 % mising_value
# BsmtFinType1 0.03 % mising_value
# BsmtFinType2 0.03 % mising_value
# Electrical 0.0 % mising_value
# FireplaceQu 0.47 % mising_value
# GarageType 0.06 % mising_value
# GarageYrBlt 0.06 % mising_value
# GarageFinish 0.06 % mising_value
# GarageQual 0.06 % mising_value
# GarageCond 0.06 % mising_value
# PoolQC 1.0 % mising_value
# Fence 0.81 % mising_value
# MiscFeature 0.96 % mising_value

# %%
for i in feature_null:
    df_copy=df.copy()
    df_copy[i]=np.where(df_copy[i].isnull(),1,0)
    df_copy.groupby(i)['SalePrice'].sum().plot.bar()
    plt.title(i)
    plt.show()

# %%
#numrical data
numrical_feature=[i for i in df if df[i].dtype!=object]#columns numrical
numrical_feature
# Out:
# ['Id',
#  'MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %%
year_feature=[i for i in numrical_feature if "Year" in i or "Yr" in i]
df[year_feature]
# Out:
#       YearBuilt  YearRemodAdd  GarageYrBlt  YrSold
# 0          2003          2003       2003.0    2008
# 1          1976          1976       1976.0    2007
# 2          2001          2002       2001.0    2008
# 3          1915          1970       1998.0    2006
# 4          2000          2000       2000.0    2008
# ...         ...           ...          ...     ...
# 1455       1999          2000       1999.0    2007
# 1456       1978          1988       1978.0    2010
# 1457       1941          2006       1941.0    2010
# 1458       1950          1996       1950.0    2010
# 1459       1965          1965       1965.0    2008
#
# [1460 rows x 4 columns]

# %%
df_copy1=df.copy()
for i in year_feature:
    if i!="YrSold":
       
        df_copy1[i]=df_copy1["YrSold"]-df_copy1[i]
        plt.scatter(df_copy1[i],df_copy1['SalePrice'])
        plt.xlabel(i)
        plt.ylabel('SalePrice')
        plt.show()
df_copy1
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
discreat_featuere=[i for i in numrical_feature if len(df[i].unique())<25 and i not in year_feature+['Id'] ]
len(discreat_featuere)
# Out:
# 17

# %%
df[discreat_featuere]
# Out:
#       MSSubClass  OverallQual  OverallCond  LowQualFinSF  BsmtFullBath  \
# 0             60            7            5             0             1
# 1             20            6            8             0             0
# 2             60            7            5             0             1
# 3             70            7            5             0             1
# 4             60            8            5             0             1
# ...          ...          ...          ...           ...           ...
# 1455          60            6            5             0             0
# 1456          20            6            6             0             1
# 1457          70            7            9             0             0
# 1458          20            5            6             0             1
# 1459          20            5            6             0             1
#
#       BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# ...

# %%
df_copy2=df.copy()
for i in discreat_featuere:
        df_copy2.groupby(i)['SalePrice'].median().plot.bar()
        
        plt.xlabel(i)
        plt.ylabel('SalePrice')
        plt.show()

# %%
continous_featuere=[i for i in numrical_feature if i not in discreat_featuere+year_feature+['Id']]
len(continous_featuere)
# Out:
# 16

# %%
df_copy3=df.copy()
for i in continous_featuere:
    df_copy3[i].hist(figsize=(10,2),bins=10)
    plt.xlabel(i)
    plt.ylabel("count")
    plt.title(i)
    plt.show()

# %% [markdown]
# # OUTLIERS
# # box blot

# %%
df_copy3=df.copy()
for i in continous_featuere:
    df_copy3.boxplot(column=i)
    plt.ylabel(i)
    plt.title(i)
    plt.show()

# %% [markdown]
# # catogaric feature

# %%
catogaric_feature=[i for i in df if df[i].dtype=="O"]
catogaric_feature
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
df_copy3=df.copy()
for i in catogaric_feature:
    df_copy3.groupby(i)['SalePrice'].median().plot.bar()
    plt.xlabel(i)
    plt.ylabel('SalePrice')
    plt.title(i)
    plt.show()

# %% [markdown]
# # fill  missig value

# %%
feature_nan_catgoric=[i for i in df if df[i].isnull().sum()>1 and df[i].dtype=="O"]
df[feature_nan_catgoric]
# Out:
#      Alley MasVnrType BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 0      NaN    BrkFace       Gd       TA           No          GLQ
# 1      NaN       None       Gd       TA           Gd          ALQ
# 2      NaN    BrkFace       Gd       TA           Mn          GLQ
# 3      NaN       None       TA       Gd           No          ALQ
# 4      NaN    BrkFace       Gd       TA           Av          GLQ
# ...    ...        ...      ...      ...          ...          ...
# 1455   NaN       None       Gd       TA           No          Unf
# 1456   NaN      Stone       Gd       TA           No          ALQ
# 1457   NaN       None       TA       Gd           No          GLQ
# 1458   NaN       None       TA       TA           Mn          GLQ
# 1459   NaN       None       TA       TA           No          BLQ
#
#      BsmtFinType2 FireplaceQu GarageType GarageFinish GarageQual GarageCond  \
# 0             Unf         NaN     Attchd          RFn         TA         TA
# ...

# %%
for i in feature_nan_catgoric:
    print(i," ",np.round(df[i].isnull().mean(),2))
# Out:
# Alley   0.94
# MasVnrType   0.01
# BsmtQual   0.03
# BsmtCond   0.03
# BsmtExposure   0.03
# BsmtFinType1   0.03
# BsmtFinType2   0.03
# FireplaceQu   0.47
# GarageType   0.06
# GarageFinish   0.06
# GarageQual   0.06
# GarageCond   0.06
# PoolQC   1.0
# Fence   0.81
# MiscFeature   0.96

# %%
def fill_nan_value(df,features):
    df_copy=df.copy()
    df_copy[features]=df_copy[features].fillna("missin value")
    return df_copy
fill_nan_value(df,feature_nan_catgoric)
print(i," ",np.round(df[i].isnull().mean(),2))
# Out:
# MiscFeature   0.96

# %%
feature_nanvalue_numrical=[i for i in df if df[i].isnull().sum()>1 and df[i].dtype!="O"]
df['LotFrontage'].isnull().sum()
# Out:
# 259

# %%
for i in feature_nanvalue_numrical:
    median_value=df[i].median()
    df[i+'nan']=np.where(df[i].isnull(),1,0)
    df[i].fillna(median_value,inplace=True)

# %%
df[feature_nanvalue_numrical].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %%
df=pd.get_dummies(df)#conver catagric or string  data to 0,1

# %%
x=df.drop(['Id','SalePrice'],axis=1)
y=df['SalePrice']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=250)

# %%
x_train
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 1328          50         60.0    10440            6            7       1920
# 241           30         40.0     3880            5            9       1945
# 1302          60         92.0    10120            8            5       1994
# 927           60         69.0     9900            7            5       1968
# 243          160         75.0    10762            6            6       1980
# ...          ...          ...      ...          ...          ...        ...
# 265           20         78.0    12090            6            6       1981
# 1408          70         60.0     7740            4            7       1910
# 373           20         79.0    10634            5            6       1953
# 1017         120         69.0     5814            8            5       1984
# 626           20         69.0    12342            5            5       1960
#
# ...

# %%
x_test.shape[0]
# Out:
# 250

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
lr.score(x_train,y_train)
# Out:
# 0.9454782491222075

# %%
y_pred=lr.predict(x_test)
from sklearn.metrics import mean_squared_error
mean_squared_error(y_pred,y_test)
# Out:
# 1378428996.9376903
